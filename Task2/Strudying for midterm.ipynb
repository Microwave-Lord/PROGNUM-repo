# %%
from math import exp, log

exp(log(2.11))
# Out:
# 2.11

# %%
from math import factorial

factorial(100)
#the maximum values for integer numbers is that they cannot exceed 4300 digits
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
a = b = [1,2,3,4]
c = b
a[2] = 0 
print(c)
# Out:
# [1, 2, 0, 4]

# %%
import math
sin(30)
# Out:
# -0.9880316240928618

# %%
from math import sin

sin(30)
# Out:
# -0.9880316240928618

# %%
from math import sin as hewwoo

hewwoo(30)
# Out:
# -0.9880316240928618
