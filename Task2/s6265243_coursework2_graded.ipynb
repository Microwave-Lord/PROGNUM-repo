# %% [markdown]
# # Coursework Set Week 2

# %% [markdown]
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: Olivier Assenberg
# * Username: oassenberg
# * Student number: S6265243
# * Group (AS1, etc.): AS3
#
# -----

# %%
totalpoints = currentpoints = 0

# %% [markdown]
# ### Julian Date, a algorithm with some pitfalls (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# In the online article: [A one-line algorithm for Julian Date](http://adsabs.harvard.edu/full/1983IAPPP..13...16F)
# we find an old and very compact formula for programmable calculators to calculate a Julian Date given a day, month and year.
# A Julian Date is in fact a
# day number corresponding to the number of elapsed days since the beginning of a cycle of 7980 years.
# That makes it a useful tool to calculate how many days there are between two dates.
# The one-line algorithm is valid for the period that started in 1582 with the Gregorian calendar.
# The formula from the article is:
#
#
# ``JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5``
#
# The article notes: **It is important to note that after all divisions in this expression only that portion of the
# quotient to the left of the decimal point is retained and that the quotient is not rounded off.**
#
# * Use your notebook to develop an implementation of this formula.
# * Then create a Python script called ``JD.py`` that asks a user to enter day, month and year. For this date, the script calculates the Julian Date (JD) and prints it. The day can be entered as a floating point number to allow for fractional days.
# * Upload your JD.py to your GitHub account -- ``PROGNUM-repo``, and set your account to be public. In your answer, provide your GitHub repository link.
# * The article provides a test case: the Julian Date for January 4, 1700 is 2341975.5.
#   Use your code to get the correct result, and attach your screen shot in this notebook.&nbsp;
#
# Extend the program on the notebook, so that it can calculate the number of days between two dates in the Gregorian calendar. What is your age expressed in days?
#
# **Answers**:

# %%
# import math
#calculating julian date LMAOOO
a = input("what do you wanna calculate? typing 'date' allows you to calculate the julian date, typing 'Difference' calculates the difference in julian date!")
# a asks the user what function they would like to receive


if a == "date": 
    D = float(input("What day?"))
    M = int(input("What month (use numbers please!"))
    Y = int(input("What year?"))

    if 1 <= M <= 12 and -5954 < Y: #this checks if the user has inputed a date where the month is a real month, and where the year fits within the 7890 year range
        JD = 367*Y -7*(Y+(M+9)//12)/4 - 3*((Y+(M-9)//7)//100 + 1)//4 + (275*M)//9 + D + 1721029-0.5
        print(f"{JD} is the julian date!")

    else:
        print("not a valid date!")



elif a == "Difference":
    print("please input the more recent date first") #this clarifies how the user should use the program
    D2 = float(input("Whats the first day?"))
    M2 = int(input("Whats the first month (use numbers please!"))
    Y2 = int(input("Whats the first year?"))

    D = float(input("Whats the second day?"))
    M = int(input("Whats the second month (use numbers please!"))
    Y = int(input("Whats the second year?")) 

    if 1 <= M <= 12 and -5954 < Y and 1 <= M <= 12 and Y <= Y2: #this checks that Y2 (the first year) is larger or the same as the second year, such that the code does not give a negative date
        JD2 = 367*Y2 -7*(Y2+(M2+9)//12)/4 - 3*((Y2+(M2-9)//7)//100 + 1)//4 + (275*M2)//9 + D2 + 1721029-0.5 - (367*Y -7*(Y+(M+9)//12)/4 - 3*((Y+(M-9)//7)//100 + 1)//4 + (275*M)//9 + D + 1721029-0.5)
        print(f"{JD2} is the julian date difference!")

    else:
        print("not a valid result!")
# Out:
# what do you wanna calculate? typing 'date' allows you to calculate the julian date, typing 'Difference' calculates the difference in julian date! 1

# %% [markdown]
# ![image.png](attachment:df7e79fa-2619-4c90-88ed-8243fc923465.png)

# %% [markdown]
# https://github.com/Microwave-Lord/PROGNUM-repo
# This is the link to the github repository; the JD file is under Task 2!

# %% [markdown]
# <div class="warning" style='background-color:#C9E4FD; color: #004280; border-left: solid #0363BC 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>ℹ️</span> INFORMATION</b><br><br>
#     The JD is only possible from 1582 onwards...

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 4

# %% [markdown]
# ###  Calculating the roots of a second degree polynomial (3 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Use your notebook to develop the necessary code and then which solves for the roots
# of $f(x)=ax^2+bx+c$ for values of ``a``, ``b`` and ``c`` entered by a user of your program.
# All the required information related to this question is included in the notebook about conditions.
#
# You have to remember that
#
# $$f(x)=ax^2+bx+c$$
#
# has two solutions:
#
# $$x_1=\frac{-b + \sqrt{b^2-4ac}}{2a} \quad\text{and}\quad x_2=\frac{-b - \sqrt{b^2-4ac}}{2a}$$
#
# only if:
#
# $$\begin{split}D= b^2-4ac>0\end{split}$$
#
# It has one solution if $D == 0$ and no solutions (at least no real solutions) if $D < 0$.
#
# * Use the ``if,elif,else`` construct to print either two solutions, one solution or an message that no solutions
#  could be found.
# * Use f-strings for your output if there are solutions.
# * Include your code with an input example and its output in your notebook.
# * Use your notebook code to create a script called ``abc.py``.
# * On Terminal, run your python script, screenshot the result, and attach the it here.
#
# **Answer**:

# %%
# import math
a = float(input("Whats the value of a?"))
b = float(input("Whats the value of b?"))
c = float(input("Whats the value of c?"))
D = b**2-4*a*c
#This asks the user for the coefficients of the expression, and immediately calculates D


if D > 0: #the case where the equation has two real roots
    x1 = (-b + ((b**2-4*a*c)**(1/2)))/(2*a)
    x2 = (-b - ((b**2-4*a*c)**(1/2)))/(2*a)
    print(f"The equation has two solutions! x1 is equal to {x1}, and x2 is equal to {x2}")

elif D == 0: #the case where the equation has 1 real root
    x = -b/(2*a)
    print(f"the equation has one solution: x = {x}")

else: #the case with no real roots
    print("this equation has no real solutions :(")

#If you input a = 1, b = -2 and c = 1, then the code gives you that this equation has one solution, namely, x = 1.
# Out:
# Whats the value of a? 1
# Whats the value of b? 2
# Whats the value of c? 1
# the equation has one solution: x = -1.0

# %% [markdown]
# ![image.png](attachment:6616c74f-1d11-4c6a-b402-b326fafdaa1a.png)

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 3

# %% [markdown]
# ### Uniqueness in lists using the `set` object (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given two lists with a number of gamma ray bursts per night for two different periods
#
# ```python
#     night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
#     night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
# ```
#
# Use Python sequence type `set` to create a **list**:
#
# 1. with values that are both in `night1` and `night2`.
# 1. with values that are the difference between `night1` and `night2`.
# 1. with values that contains all items from both sets, duplicates are excluded.
# 1. after an update of `night1` by removing all its elements that are not available in `night2`.
#
# **Answers**:

# %%
import math
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

a = set(night1)
b = set(night2)
#converts both lists into sets


c = list(a.intersection(b)) #finds the intersection (the common values)
d = list(a.difference(b)) #finds the values of night1 which are not in night2
e = list(a.union(b)) #creates a list which contains a singular instance of each value of night1 AND night2 (only lists repeating values once)



for i in d:
    night1.remove(i) #simple loop to remove the elements which are not in night2 from night1


print(f"the common values of night 1 and two are {c}")
print(f"the difference between night 1 and night 2 is {d}")
print(f"the union of night 1 and night 2 is {e}")
print(f"the updated night 1 is {night1}")
# Out:
# the common values of night 1 and two are [0, 1, 2, 3, 4]
# the difference between night 1 and night 2 is [9, 5, 7]
# the union of night 1 and night 2 is [0, 1, 2, 3, 4, 5, 7, 9]
# the updated night 1 is [1, 3, 2, 4, 0, 3, 2, 2, 4, 3]

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 2

# %% [markdown]
# ### Change a value in a dictionary (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given the Python dictionary:
#
# ```python
# planetsmass = { 'Mercury' : 0.33,
#                 'Venus'   : 4.87, 'Earth'   : 5.98,
#                 'Mars'    : 0.65, 'Jupiter' : 1900,
#                 'Saturn'  :  570, 'Uranus'  :  87,
#                 'Neptune' :  100, 'Pluto'   :  0.7 }
# ```
#
# 1. Extract from this dictionary a Python **list** with only the names of the objects.
# 1. Print the mass of Venus in Earth masses.
# 1. Remove Pluto from your dictionary.
# 1. Add Planet Nine with mass 29.3 to the dictionary.
# 1. Print the modified dictionary.
#
#
# **Answer**:

# %%
planetsmass = { 'Mercury' : 0.33,
                'Venus'   : 4.87, 'Earth'   : 5.98,
                'Mars'    : 0.65, 'Jupiter' : 1900,
                'Saturn'  :  570, 'Uranus'  :  87,
                'Neptune' :  100, 'Pluto'   :  0.7 }

c = (list(planetsmass.keys())) #converts the 'keys' (the names of the planets) of the dictionary into a list
print(c)
a = list(planetsmass.values()) #converts the 'values' (the masses) of the dictionary into a list

b = planetsmass['Venus']/planetsmass['Earth'] #divides the mass of venus by the mass of earth to find the mass of venus in terms of the mass of earth
print(f"the mass of venus in earth masses is {b}")

planetsmass.pop('Pluto') #the .pop here removes the 'pluto' entry (key and value) from the dictionary
planetsmass['Planet Nine'] = 29.3 #adds a new key called 'Planet Nine' and assigns the value 29.3 to it

print(planetsmass)
# Out:
# ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune', 'Pluto']
# the mass of venus in earth masses is 0.81438127090301
# {'Mercury': 0.33, 'Venus': 4.87, 'Earth': 5.98, 'Mars': 0.65, 'Jupiter': 1900, 'Saturn': 570, 'Uranus': 87, 'Neptune': 100, 'Planet Nine': 29.3}

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 2

# %% [markdown]
# ### Apply NumPy functions to data (2pt) <font color='red'><b>COURSEWORK</b></font>
#
# * Create a NumPy array `x` with 100 angles in degrees between 0 and 360 degrees using ``np.linspace()``
# * Calculate the ``np.sinc(x)`` values of ``x``, with ``x`` in radians. The definition of the sinc function is:
#
#   $$\mathrm{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$$
#
# * Print the first 10 values of the result.
#
# **Answer**

# %%
import numpy as np
import math

a = np.linspace(0, 360, 100) #generates 100 values between 0 and 360 degrees with equal spacing

b = (a*math.pi)/180 #converts from degrees to radians

c = np.sinc(b)

for i in range (10): #loop to print the first 10 values of the np.sinc() function
    print(c[i])
    i = i+1
# Out:
# 1.0
# 0.9933873652026526
# 0.9737067586290185
# 0.9414256204351539
# 0.8973083104869668
# 0.842394523762147
# 0.7779700080257624
# 0.705530483396262
# 0.6267398696896892
# 0.5433840979844083

# %% [markdown]
# <div class="warning" style='background-color:#C9E4FD; color: #004280; border-left: solid #0363BC 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>ℹ️</span> INFORMATION</b><br><br>
#     Your code is correct, however it can be improved. You could also do something like: <br>
#
#     x = np.linspace(o, 360, 100)
#     y = np.sinc(np.radians(x))
#     print(y[:10])
# ```

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 2

# %% [markdown]
# #### Finishing up
#
# **Please read the section about your report in the task documentation very carefully before submitting it to BrightSpace.**
#
# ------------

# %% [markdown]
# ## T.A. Grading

# %%
#### Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1) if totalpoints != 0 else 0
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
# Out:
# Total number of points: 13. Student score: 13.  Task Grade = 10.0
