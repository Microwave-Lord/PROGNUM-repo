# %%
import numpy 
from numpy import sin, cos, exp, pi
import scipy as sp



fun = input("f(x) = ")


while True:
    try:
        a = eval(input("lower bound?"))
        b = eval(input("upper bound"))
        n = int(input("number of points!"))
        break
    except ValueError:
        print("You didnt put a number for one of the prompts!")
        


res, error = sp.integrate.quad(lambda x: x**4 + exp(sin(x)+cos(x)), a, b)
print(res)

x = numpy.random.uniform(a, b, n)



monte_carlo = ((b-a)/n)*numpy.sum(eval(fun))
print(monte_carlo)
# Out:
# f(x) =  x**4 + exp(sin(x)+cos(x))
# lower bound? 0
# upper bound pi
# number of points! 10000
# 68.72932272689113
# 69.93760156607065
