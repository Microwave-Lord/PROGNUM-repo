# %% [markdown]
# Answers for Week 1
#
# * Name: olivier assenberg
# * Username: oassenberg
# * Student s-number: s6265243
# * Group (AS1, etc.): AS3

# %%
#Question 1.2
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
#Question 1.2
pi = 22/7 # Processed on Jupyter Hub

# %%
#Question 1.3
import math
x=6
x*=5
x*=4
x*=3
x*=2
x*=1
print(x)
# Out:
# 720

# %%
#Question 1.4
import math

f = 2.42 * 10**28
h = 6.63 * 10**(-34)

E = h*f
print(E)
# Out:
# 1.6044599999999995e-05

# %%
#Question 1.5

import math
from scipy.constants import G

M_e = 5.9722 * 10**24 #Mass of the earth in kg
M_m = 7.342 * 10**22 #mass of the moon in kg
d = 385000.6 * 10**3  #distance between the earth and the moon in meters

F = (G*M_e*M_m)/(d**2) #the gravitational force in newtons between the two bodies

print(F)
# Out:
# 1.9743840518075715e+20

# %%
#Question 1.7

x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")

#This code prints the first number, then prints the second number directly besides it with no seperation!
# Out:
# 103.142857142857143

# %% [markdown]
# #Question 1.10
# ![Screenshot%202026-02-11%20153258.png](attachment:Screenshot%202026-02-11%20153258.png)

# %% [markdown]
# ![Screenshot%20from%202026-02-11%2015-58-19.png](attachment:Screenshot%20from%202026-02-11%2015-58-19.png)
